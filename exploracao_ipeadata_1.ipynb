# %% [markdown]
# # Importação

# %%
import ipeadatapy as ipea
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import ipeadatapy as ipea
#
# ModuleNotFoundError: No module named 'ipeadatapy'

# %%
help(ipea.themes)
# Out:
# Help on function themes in module ipeadatapy.themes:
#
# themes(theme_id=None, name=None, macro=None, regional=None, social=None)
#     :param theme_id: Theme ID by which the return will be filtered
#     :type theme_id: int, optional
#     :param name: Theme name by which the return will be filtered
#     :type name: str, optional
#     :param macro: If macro=1, the function will return only themes related to the Macroeconomics big theme
#     :type macro: int, optional
#     :param regional: If regional=1, the function will return only themes related to the Regional big theme
#     :type regional: int, optional
#     :param social: If social=1, the function will return only themes related to the Social big theme
#     :type social: int, optional
#     :return: Returns available Ipeadata themes
#     :rtype: pandas.DataFrame

# %%
ipea.themes()
# Out:
#     ID                     NAME  MACRO  REGIONAL  SOCIAL
# 0   28             Agropecuária    NaN       1.0     NaN
# 1   23       Assistência social    NaN       NaN     1.0
# 2   25     Avaliação do governo    NaN       NaN     NaN
# 3   10    Balanço de pagamentos    1.0       NaN     NaN
# 4    7                   Câmbio    1.0       NaN     NaN
# 5    5        Comércio exterior    1.0       1.0     NaN
# 6    2         Consumo e vendas    1.0       1.0     NaN
# 7    8         Contas nacionais    1.0       NaN     NaN
# 8   81         Contas Regionais    NaN       1.0     NaN
# 9   24       Correção monetária    1.0       NaN     NaN
# 10  82                  COVID19    NaN       1.0     NaN
# 11  37               Demografia    NaN       NaN     1.0
# 12  54        Deputado Estadual    NaN       1.0     NaN
# 13  55         Deputado Federal    NaN       1.0     NaN
# 14  38   Desenvolvimento humano    NaN       NaN     1.0
# ...

# %%
ipea.themes(macro=1)
# Out:
#     ID                     NAME  MACRO  REGIONAL  SOCIAL
# 3   10    Balanço de pagamentos    1.0       NaN     NaN
# 4    7                   Câmbio    1.0       NaN     NaN
# 5    5        Comércio exterior    1.0       1.0     NaN
# 6    2         Consumo e vendas    1.0       1.0     NaN
# 7    8         Contas nacionais    1.0       NaN     NaN
# 9   24       Correção monetária    1.0       NaN     NaN
# 15  11   Economia internacional    1.0       NaN     NaN
# 19  12                  Emprego    1.0       1.0     NaN
# 20  19       Estoque de capital    1.0       1.0     NaN
# 21   6        Finanças públicas    1.0       1.0     NaN
# 22  39              Financeiras    1.0       NaN     NaN
# 29  15      Indicadores sociais    1.0       NaN     NaN
# 32   3          Moeda e crédito    1.0       1.0     NaN
# 33  27  Percepção e expectativa    1.0       NaN     NaN
# 34  14                População    1.0       1.0     NaN
# ...

# %%
ipea.themes(theme_id=17)
# Out:
#     ID                    NAME  MACRO  REGIONAL  SOCIAL
# 45  17  Sinopse macroeconômica    1.0       NaN     NaN

# %%
help(ipea.metadata)
# Out:
# Help on function metadata in module ipeadatapy.metadata:
#
# metadata(series=None, big_theme=None, source=None, country=None, frequency=None, unit=None, measure=None, status=None, source_ext=None, source_url=None, last_update=None, code=None, comment=None, name=None, numerica=None, theme_id=None)
#     :param series: Time series code.
#     :type series: str, optional
#     :param big_theme: Big theme by which the return will be fitered. Options: "Macroeconômico", "Regional" or "Social"
#     :type big_theme: str, optional
#     :param source: Source by which the return will be filtered. For available sources run sources() function.
#     :type source: str, optional
#     :param country: Country ID by which the return will be filtered. For available countries and their IDs run countries() function.
#     :type country: str, optional
#     :param frequency: Frequency by which the return will be filtered.
#     :type frequency: str, optional
# ...

# %%
ipea.metadata()
# Out:
#                     CODE                                               NAME  \
# 0           ABATE_ABPEAV                   Abate - aves - peso das carcaças
# 1           ABATE_ABPEBV                Abate - bovinos - peso das carcaças
# 2           ABATE_ABPESU                 Abate - suínos - peso das carcaças
# 3           ABATE_ABQUAV                          Abate - aves - quantidade
# 4           ABATE_ABQUBV                       Abate - bovinos - quantidade
# ...                  ...                                                ...
# 8903             PIBVRAE  PIB Estadual - valor adicionado a preços const...
# 8904            VPRODPIN              Valor da produção - Indústria - Total
# 8905       COVID19_CASOS                            Casos de COVID19 no dia
# 8906   COVID19_CASOSACUM             Casos de COVID19, acumulados até o dia
# 8907  COVID19_OBITOSACUM           Óbitos por COVID19, acumulados até o dia
#
# ...

# %%
ipea.metadata(big_theme='Macroeconômico')
# Out:
#                      CODE                                  NAME  \
# 0            ABATE_ABPEAV      Abate - aves - peso das carcaças
# 1            ABATE_ABPEBV   Abate - bovinos - peso das carcaças
# 2            ABATE_ABPESU    Abate - suínos - peso das carcaças
# 3            ABATE_ABQUAV             Abate - aves - quantidade
# 4            ABATE_ABQUBV          Abate - bovinos - quantidade
# ...                   ...                                   ...
# 8032   VALOR12_GLOBAL2712  Bônus global República (27) - spread
# 8033   VALOR12_GLOBAL4012  Bônus global República (40) - spread
# 8034    VALOR12_GLOBAL912   Bônus global República (9) - spread
# 8035    VALOR12_TJCBOND12                       C-Bond - spread
# 8036  VALOR366_TJCBOND366                       C-Bond - spread
#
#                                                 COMMENT  \
# 0     O abate de animais é mensurado por sua quantid...
# 1     O abate de animais é mensurado por sua quantid...
# ...

# %%
ipea.metadata(big_theme='Macroeconômico').to_csv('variaveis_macroeconomicas_ipeadata', sep=';')
